# %% [markdown]
# # Pandas Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\aryan\Downloads\reviews.csv\reviews.csv")
df
# Out:
#         key          author        date  stars  \
# 0      0_bj  Ilovebennjerry  2017-04-15      3
# 1      0_bj   Sweettooth909  2020-01-05      5
# 2      0_bj       LaTanga71  2018-04-26      3
# 3      0_bj      chicago220  2018-01-14      5
# 4      0_bj        Kassidyk  2020-07-24      1
# ...     ...             ...         ...    ...
# 7938  56_bj   Shellyshellzs  2020-04-30      5
# 7939  56_bj          Or1234  2020-02-24      5
# 7940  56_bj           ava21  2020-01-31      5
# 7941  56_bj            yeee  2019-03-13      5
# 7942  56_bj        Ellehcar  2020-07-24      5
#
#                                    title  helpful_yes  helpful_no  \
# 0                   Not enough brownies!           10           3
# 1           I’m OBSESSED with this pint!            3           0
# 2      My favorite...More Caramel Please            5           2
# 3                            Obsessed!!!           24           1
# ...

# %%
df = df.set_index('date')
df
# Out:
#               key          author  stars                               title  \
# date
# 2017-04-15   0_bj  Ilovebennjerry      3                Not enough brownies!
# 2020-01-05   0_bj   Sweettooth909      5        I’m OBSESSED with this pint!
# 2018-04-26   0_bj       LaTanga71      3   My favorite...More Caramel Please
# 2018-01-14   0_bj      chicago220      5                         Obsessed!!!
# 2020-07-24   0_bj        Kassidyk      1               Worst Ice Cream Ever!
# ...           ...             ...    ...                                 ...
# 2020-04-30  56_bj   Shellyshellzs      5          Peanut butter fudge heaven
# 2020-02-24  56_bj          Or1234      5  The best Chocolate Ice Cream Combo
# 2020-01-31  56_bj           ava21      5                           PERFECT!!
# 2019-03-13  56_bj            yeee      5                        My favorite!
# 2020-07-24  56_bj        Ellehcar      5                            The Best
#
# ...

# %%
df.plot(kind = 'line', title = 'Ice Cream Rating', xlabel = 'Daily Rating', ylabel = 'score')
# Out:
# <Axes: title={'center': 'Ice Cream Rating'}, xlabel='Daily Rating', ylabel='score'>
