# %% [markdown]
# # Reading in Files

# %%
import pandas as pd

# %%
#untuk membaca file excel csv
csv = pd.read_csv(r"C:\Users\aryan\OneDrive\Desktop\Data Analyst\python\Python Pandas\countries of the world.csv")
csv
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
#untuk membaca file Excel (mengubah Header atau nama column)
#pd.read_csv(r"C:\Users\aryan\OneDrive\Desktop\Data Analyst\python\Python Pandas\countries of the world.csv", header = 0, names = ['Country','Region'])
#header = 0, names = ['Country','Region']
#header = 0 (akan mengawali indeks ke 0 adalah isi dari data)
#jika header = None, maka nama column yang sebelumnya akan masuk pada data
#names = ['Country','Region'] (untuk memberi nama column nya)

# %%
#untuk membaca file text
txt = pd.read_csv(r"C:\Users\aryan\OneDrive\Desktop\Data Analyst\python\Python Pandas\countries of the world.txt", sep = '\t')
txt
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
#untuk membaca file json (JavaScript Object Notation)
json = pd.read_json(r"C:\Users\aryan\OneDrive\Desktop\Data Analyst\python\Python Pandas\json_sample.json")
json
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
#untuk membaca file excel (xlsx)
#yang memiliki banyak sheet
xlsx = pd.read_excel(r"C:\Users\aryan\OneDrive\Desktop\Data Analyst\python\Python Pandas\world_population_excel_workbook.xlsx")
xlsx
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
#untuk membaca file excel (xlsx)
#yang memiliki banyak sheet
xlsx = pd.read_excel(r"C:\Users\aryan\OneDrive\Desktop\Data Analyst\python\Python Pandas\world_population_excel_workbook.xlsx", sheet_name = 'Sheet1')
xlsx
#sheet_name = 'Sheet1' (untuk menampilkan bagian sheetnya)
# Out:
#      Rank CCA3            Country           Capital
# 0      36  AFG        Afghanistan             Kabul
# 1     138  ALB            Albania            Tirana
# 2      34  DZA            Algeria           Algiers
# 3     213  ASM     American Samoa         Pago Pago
# 4     203  AND            Andorra  Andorra la Vella
# ..    ...  ...                ...               ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu
# 230   172  ESH     Western Sahara         El AaiÃºn
# 231    46  YEM              Yemen             Sanaa
# 232    63  ZMB             Zambia            Lusaka
# 233    74  ZWE           Zimbabwe            Harare
#
# [234 rows x 4 columns]

# %%
pd.set_option('display.max.rows',235)

# %%
xlsx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     234 non-null    int64
#  1   CCA3     234 non-null    object
#  2   Country  234 non-null    object
#  3   Capital  234 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 7.4+ KB

# %%
xlsx['Rank']
# Out:
# 0       36
# 1      138
# 2       34
# 3      213
# 4      203
#       ...
# 229    226
# 230    172
# 231     46
# 232     63
# 233     74
# Name: Rank, Length: 234, dtype: int64

# %%
#menampilkan data urutan pertama dari data xlsx
xlsx.head()
# Out:
#    Rank CCA3         Country           Capital
# 0    36  AFG     Afghanistan             Kabul
# 1   138  ALB         Albania            Tirana
# 2    34  DZA         Algeria           Algiers
# 3   213  ASM  American Samoa         Pago Pago
# 4   203  AND         Andorra  Andorra la Vella

# %%
#menampilkan data urutan terakhir dari data xlsx
xlsx.tail()
# Out:
#      Rank CCA3            Country    Capital
# 229   226  WLF  Wallis and Futuna   Mata-Utu
# 230   172  ESH     Western Sahara  El AaiÃºn
# 231    46  YEM              Yemen      Sanaa
# 232    63  ZMB             Zambia     Lusaka
# 233    74  ZWE           Zimbabwe     Harare

# %%
xlsx.loc[4]
# Out:
# Rank                    203
# CCA3                    AND
# Country             Andorra
# Capital    Andorra la Vella
# Name: 4, dtype: object

# %%
albania_data = xlsx[xlsx['Country'] == 'Albania']
print(albania_data)
# Out:
#    Rank CCA3  Country Capital
# 1   138  ALB  Albania  Tirana
